# %% [markdown]
# # Fania Margarita Vanoye Lizalde

# %%
print("     *")
print("    * *")
print("   *   *")
print("  *     *")
print(" ***   ***")
print("   *   *")
print("   *   * ")
print("   *   * ")
print("   ***** ")
# Out:
#      *
#     * *
#    *   *
#   *     *
#  ***   ***
#    *   *
#    *   *
#    *   *
#    *****

# %% [markdown]
# ## Un solo print

# %%
print("    *\n   * * \n  *   *\n *     *\n***   ***\n  *  *\n  *  *\n  *  *\n  ****")
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *  *
#   *  *
#   *  *
#   ****

# %% [markdown]
# ## Flecha grande

# %%
print("         *")
print("        * *")
print("       *   *")
print("      *     *")
print("     *       *")
print("    *         *")
print("   *           *")
print("  *             *")
print(" ******     ******")
print("      *     *")
print("      *     *")
print("      *     *")
print("      *     *")
print("      *******")

# %% [markdown]
# ## clonar el print

# %%
flecha = '    *\n   * *\n  *   *\n *     *\n***   ***\n  *   *\n  *   *\n  *****\n'
print(flecha * 2)
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
