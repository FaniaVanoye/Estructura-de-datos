# %%
board = (['1', '2', '3'],['4', 'X', '6'],['7', '8', '9'])

def DisplayBoard(board):
#
# la función acepta un parámetro el cual contiene el estado actual del tablero
# y lo muestra en la consola
#
    print('-----------*-------------*-----------*')
    print('|          |             |           |')
    print('|' +  board[0][0]  + '|' +  board[0][1]  + '|' +  board[0][2]  + '|')
    print('|          |             |           |')
    print('-----------*-------------*-----------*')
    print('|          |             |           |')
    print('|' +  board[1][0]  + '|' +  board[1][1]  + '|' +  board[1][2]  + '|')
    print('|          |             |           |')
    print('-----------*-------------*-----------*')
    print('|          |             |           |')
    print('|' +  board[2][0]  + '|' +  board[2][1]  + '|' +  board[2][2]  + '|')
    print('|          |             |           |')
    print('-----------*-------------*-----------*')

def EnterMove(board):
    while True:
        move = int(input('Selecciona tu movimiento(1-9):  '))
        
        if move < 1 or move > 9:
                   print('Selecciona un lugar entre el (1-9)')
                   continue 
        if str(move) not in board[0] and str(move) not in board[1] and str(move) not in board[2]:
            print('SELECCIONA UN NUMERO')
            continue
        for fila in range(0,3):
            for columna in range(0,3):
                if board[fila][columna] == str(move):
                    board[fila][columna] = 'O'            
        break
def MakeListOfFreeFields(board):
    espacios_vacios = []
    
    for fila in range(0,3):
        for columna in range(0,3):
            if board[fila][columna] == 'X' or board[fila][columna] == 'O':
                    pass     
            else:
                espacios_vacios.append(([fila],[columna]))
    print(espacios_vacios)

def VictoryFor(board, sign):
    if board[0][0] == sign and board[0][1] == sign and board[0][2] == sign:	# Verificar fila rc
            print('El jugador ', sing , 'Es el ganador')
    if board[1][0] == sign and board[1][1] == sign and board[1][2] == sign: # Verificar columna rc
            print('El jugador ', sing , 'Es el ganador')
    if board[2][0] == sign and board[2][1] == sign and board[2][2] == sign: # Verificar columna rc
            print('El jugador ', sing , 'Es el ganador')
    if board[0][0] == sign and board[1][0] == sign and board[2][0] == sign: # Verificar columna rc
            print('El jugador ', sing , 'Es el ganador')
    if board[0][1] == sign and board[1][1] == sign and board[2][1] == sign: # Verificar columna rc
            print('El jugador ', sing , 'Es el ganador')
    if board[0][2] == sign and board[1][2] == sign and board[2][2] == sign: # Verificar columna rc
            print('El jugador ', sing , 'Es el ganador')
    if board[0][0] == sign and board[1][1] == sign and board[2][2] == sign: # Verificar columna rc
            print('El jugador ', sing , 'Es el ganador')
    if board[2][0] == sign and board[1][1] == sign and board[0][2] == sign: # Verificar columna rc
            print('El jugador ', sing , 'Es el ganador')
    else:
        print('Nadie gano')
        
def DrawMove(board):
    board = (['1', '2', '3'],['4', 'X', '6'],['7', '8', '9'])
    movimientos = 1
    usuario = 'O'
    maquina = 'X'
